# %% [markdown]
# # Gov Covid API
# ### https://coronavirus.data.gov.uk/developers-guide
#
# Install library with: `pip install uk-covid19`
#
# Yesterdays data is ignored (5pm cut point) but use caution with the most recent data before that as it does increase retrospectively.

# %%
import ProcessCovidData as cv
# %matplotlib inline

# %% [markdown]
# ## Nottinghamshire

# %%
filters = ["areaType=utla", "areaName=Nottinghamshire"]
df, fig = cv.ProcessData(filters)

df.tail(8)
# Out:
#          date         areaName  newCases  newDeaths  newCases_SMA_7  \
# 8  2020-10-20  Nottinghamshire       478        5.0      362.000000
# 7  2020-10-21  Nottinghamshire       438        2.0      371.000000
# 6  2020-10-22  Nottinghamshire       447        4.0      387.714286
# 5  2020-10-23  Nottinghamshire       386        6.0      403.428571
# 4  2020-10-24  Nottinghamshire       270        2.0      401.000000
# 3  2020-10-25  Nottinghamshire       269        7.0      403.571429
# 2  2020-10-26  Nottinghamshire       468        4.0      393.714286
# 1  2020-10-27  Nottinghamshire       262        3.0      362.857143
#
#    newDeaths_SMA_7
# 8         3.285714
# 7         3.285714
# 6         3.428571
# 5         3.857143
# 4         3.428571
# 3         3.714286
# 2         4.285714
# 1         4.000000

# %% [markdown]
# ## Rushcliffe

# %%
filters = ["areaType=ltla", "areaName=Rushcliffe"]
df, fig = cv.ProcessData(filters)

df.tail(8)
# Out:
#          date    areaName  newCases  newDeaths  newCases_SMA_7  \
# 8  2020-10-20  Rushcliffe        80        1.0       66.428571
# 7  2020-10-21  Rushcliffe        69        0.0       65.142857
# 6  2020-10-22  Rushcliffe        76        1.0       66.142857
# 5  2020-10-23  Rushcliffe        72        3.0       70.285714
# 4  2020-10-24  Rushcliffe        35        2.0       66.714286
# 3  2020-10-25  Rushcliffe        47        2.0       67.428571
# 2  2020-10-26  Rushcliffe        61        0.0       62.857143
# 1  2020-10-27  Rushcliffe        29        1.0       55.571429
#
#    newDeaths_SMA_7
# 8         1.285714
# 7         1.142857
# 6         1.000000
# 5         1.142857
# 4         1.142857
# 3         1.285714
# 2         1.285714
# 1         1.285714

# %% [markdown]
# ## Sheffield

# %%
filters = ["areaType=ltla", "areaName=Sheffield"]
df, fig = cv.ProcessData(filters)

df.tail(8)
# Out:
#          date   areaName  newCases  newDeaths  newCases_SMA_7  newDeaths_SMA_7
# 8  2020-10-20  Sheffield       493        2.0      383.714286         2.857143
# 7  2020-10-21  Sheffield       437        5.0      391.714286         3.428571
# 6  2020-10-22  Sheffield       357        1.0      394.714286         3.285714
# 5  2020-10-23  Sheffield       330        5.0      394.428571         3.142857
# 4  2020-10-24  Sheffield       292        7.0      387.285714         3.428571
# 3  2020-10-25  Sheffield       242        1.0      376.285714         3.142857
# 2  2020-10-26  Sheffield       383        4.0      362.000000         3.571429
# 1  2020-10-27  Sheffield       263        4.0      329.142857         3.857143

# %% [markdown]
# ## Cambridge

# %%
filters = ["areaType=ltla", "areaName=Cambridge"]
df, fig = cv.ProcessData(filters)

df.tail(8)
# Out:
#          date   areaName  newCases  newDeaths  newCases_SMA_7  newDeaths_SMA_7
# 8  2020-10-20  Cambridge        45        0.0       29.142857         0.142857
# 7  2020-10-21  Cambridge        40        1.0       30.428571         0.285714
# 6  2020-10-22  Cambridge        45        0.0       32.428571         0.142857
# 5  2020-10-23  Cambridge        21        0.0       33.428571         0.142857
# 4  2020-10-24  Cambridge        10        0.0       33.714286         0.142857
# 3  2020-10-25  Cambridge        25        0.0       34.571429         0.142857
# 2  2020-10-26  Cambridge        30        0.0       30.857143         0.142857
# 1  2020-10-27  Cambridge        13        0.0       26.285714         0.142857
