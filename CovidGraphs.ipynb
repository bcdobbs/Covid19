# %% [markdown]
# # Gov Covid API
# ### https://coronavirus.data.gov.uk/developers-guide
#
# Install library with: `pip install uk-covid19`

# %%
import ProcessCovidData as cv
# %matplotlib inline

# %% [markdown]
# ## Nottinghamshire

# %%
filters = ["areaType=utla", "areaName=Nottinghamshire"]
df, fig = cv.ProcessData(filters)

df.tail(8)
# Out:
#          date         areaName  newCases  newDeaths  newCases_SMA_7  \
# 8  2020-10-19  Nottinghamshire       537        0.0      343.285714
# 7  2020-10-20  Nottinghamshire       478        5.0      362.000000
# 6  2020-10-21  Nottinghamshire       438        2.0      371.000000
# 5  2020-10-22  Nottinghamshire       447        4.0      387.714286
# 4  2020-10-23  Nottinghamshire       383        6.0      403.000000
# 3  2020-10-24  Nottinghamshire       260        2.0      399.142857
# 2  2020-10-25  Nottinghamshire       261        7.0      400.571429
# 1  2020-10-26  Nottinghamshire       334        2.0      371.571429
#
#    newDeaths_SMA_7
# 8         3.285714
# 7         3.285714
# 6         3.285714
# 5         3.428571
# 4         3.857143
# 3         3.428571
# 2         3.714286
# 1         4.000000

# %% [markdown]
# ## Rushcliffe

# %%
filters = ["areaType=ltla", "areaName=Rushcliffe"]
df, fig = cv.ProcessData(filters)

df.tail(8)
# Out:
#          date    areaName  newCases  newDeaths  newCases_SMA_7  \
# 8  2020-10-19  Rushcliffe        93        0.0       65.714286
# 7  2020-10-20  Rushcliffe        80        1.0       66.428571
# 6  2020-10-21  Rushcliffe        69        0.0       65.142857
# 5  2020-10-22  Rushcliffe        76        1.0       66.142857
# 4  2020-10-23  Rushcliffe        72        3.0       70.285714
# 3  2020-10-24  Rushcliffe        34        2.0       66.571429
# 2  2020-10-25  Rushcliffe        46        2.0       67.142857
# 1  2020-10-26  Rushcliffe        49        0.0       60.857143
#
#    newDeaths_SMA_7
# 8         1.285714
# 7         1.285714
# 6         1.142857
# 5         1.000000
# 4         1.142857
# 3         1.142857
# 2         1.285714
# 1         1.285714

# %% [markdown]
# ## Cambridge

# %%
filters = ["areaType=ltla", "areaName=Cambridge"]
df, fig = cv.ProcessData(filters)

df.tail(8)
# Out:
#          date   areaName  newCases  newDeaths  newCases_SMA_7  newDeaths_SMA_7
# 8  2020-10-19  Cambridge        56        0.0       28.285714         0.285714
# 7  2020-10-20  Cambridge        45        0.0       29.142857         0.142857
# 6  2020-10-21  Cambridge        40        1.0       30.428571         0.285714
# 5  2020-10-22  Cambridge        45        0.0       32.428571         0.142857
# 4  2020-10-23  Cambridge        21        0.0       33.428571         0.142857
# 3  2020-10-24  Cambridge        10        0.0       33.714286         0.142857
# 2  2020-10-25  Cambridge        24        0.0       34.428571         0.142857
# 1  2020-10-26  Cambridge        16        0.0       28.714286         0.142857
