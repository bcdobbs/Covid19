# %% [markdown]
# # Gov Covid API
# ### https://coronavirus.data.gov.uk/developers-guide
#
# Install library with: `pip install uk-covid19`
#
# Yesterdays data is ignored (5pm cut point) but use caution with the most recent data before that as it does increase retrospectively.

# %%
import ProcessCovidData as cv
# %matplotlib inline

# %% [markdown]
# ## Nottinghamshire

# %%
filters = ["areaType=utla", "areaName=Nottinghamshire"]
df, fig = cv.ProcessData(filters)

df.tail(8)
# Out:
#          date         areaName  newCases  newDeaths  newCases_SMA_7  \
# 8  2020-10-21  Nottinghamshire       438        2.0      370.714286
# 7  2020-10-22  Nottinghamshire       447        4.0      387.428571
# 6  2020-10-23  Nottinghamshire       388        7.0      403.428571
# 5  2020-10-24  Nottinghamshire       271        2.0      401.142857
# 4  2020-10-25  Nottinghamshire       272        7.0      404.142857
# 3  2020-10-26  Nottinghamshire       479        4.0      396.142857
# 2  2020-10-27  Nottinghamshire       387        3.0      383.142857
# 1  2020-10-28  Nottinghamshire       282        6.0      360.857143
#
#    newDeaths_SMA_7
# 8         3.428571
# 7         3.571429
# 6         4.000000
# 5         3.571429
# 4         3.857143
# 3         4.428571
# 2         4.142857
# 1         4.714286

# %% [markdown]
# ## Rushcliffe

# %%
filters = ["areaType=ltla", "areaName=Rushcliffe"]
df, fig = cv.ProcessData(filters)

df.tail(8)
# Out:
#          date    areaName  newCases  newDeaths  newCases_SMA_7  \
# 8  2020-10-21  Rushcliffe        69        0.0       65.000000
# 7  2020-10-22  Rushcliffe        76        1.0       66.000000
# 6  2020-10-23  Rushcliffe        72        3.0       70.142857
# 5  2020-10-24  Rushcliffe        35        2.0       66.571429
# 4  2020-10-25  Rushcliffe        47        2.0       67.285714
# 3  2020-10-26  Rushcliffe        62        0.0       63.000000
# 2  2020-10-27  Rushcliffe        42        1.0       57.571429
# 1  2020-10-28  Rushcliffe        36        0.0       52.857143
#
#    newDeaths_SMA_7
# 8         1.142857
# 7         1.000000
# 6         1.142857
# 5         1.142857
# 4         1.285714
# 3         1.285714
# 2         1.285714
# 1         1.285714

# %% [markdown]
# ## Sheffield

# %%
filters = ["areaType=ltla", "areaName=Sheffield"]
df, fig = cv.ProcessData(filters)

df.tail(8)
# Out:
#          date   areaName  newCases  newDeaths  newCases_SMA_7  newDeaths_SMA_7
# 8  2020-10-21  Sheffield       437        5.0      391.571429         3.428571
# 7  2020-10-22  Sheffield       356        1.0      394.428571         3.285714
# 6  2020-10-23  Sheffield       330        5.0      394.142857         3.142857
# 5  2020-10-24  Sheffield       301        7.0      388.285714         3.428571
# 4  2020-10-25  Sheffield       262        1.0      380.142857         3.142857
# 3  2020-10-26  Sheffield       408        4.0      369.571429         3.571429
# 2  2020-10-27  Sheffield       314        4.0      344.000000         3.857143
# 1  2020-10-28  Sheffield       213        0.0      312.000000         3.142857

# %% [markdown]
# ## Cambridge

# %%
filters = ["areaType=ltla", "areaName=Cambridge"]
df, fig = cv.ProcessData(filters)

df.tail(8)
# Out:
#          date   areaName  newCases  newDeaths  newCases_SMA_7  newDeaths_SMA_7
# 8  2020-10-21  Cambridge        40        2.0       30.428571         0.428571
# 7  2020-10-22  Cambridge        45        0.0       32.428571         0.285714
# 6  2020-10-23  Cambridge        21        0.0       33.428571         0.285714
# 5  2020-10-24  Cambridge        10        0.0       33.714286         0.285714
# 4  2020-10-25  Cambridge        25        0.0       34.571429         0.285714
# 3  2020-10-26  Cambridge        31        0.0       31.000000         0.285714
# 2  2020-10-27  Cambridge        37        0.0       29.857143         0.285714
# 1  2020-10-28  Cambridge        23        0.0       27.428571         0.000000
