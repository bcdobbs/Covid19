# %% [markdown]
# # Gov Covid API
# ### https://coronavirus.data.gov.uk/developers-guide
#
# Install library with: `pip install uk-covid19`
#
# Yesterdays data is ignored (5pm cut point) but use caution with the most recent data before that as it does increase retrospectively.

# %%
import ProcessCovidData as cv
# %matplotlib inline

# %% [markdown]
# ## Nottinghamshire

# %%
filters = ["areaType=utla", "areaName=Nottinghamshire"]
df, fig = cv.ProcessData(filters)

df.tail(8)
# Out:
#          date         areaName  newCases  newDeaths  newCases_SMA_7  \
# 8  2020-10-28  Nottinghamshire       438        8.0      393.285714
# 7  2020-10-29  Nottinghamshire       449        8.0      393.428571
# 6  2020-10-30  Nottinghamshire       446        8.0      401.571429
# 5  2020-10-31  Nottinghamshire       300        7.0      405.714286
# 4  2020-11-01  Nottinghamshire       234        6.0      400.285714
# 3  2020-11-02  Nottinghamshire       577       10.0      411.285714
# 2  2020-11-03  Nottinghamshire       426       10.0      410.000000
# 1  2020-11-04  Nottinghamshire       123       13.0      365.000000
#
#    newDeaths_SMA_7
# 8         6.142857
# 7         6.285714
# 6         6.428571
# 5         6.857143
# 4         6.714286
# 3         7.428571
# 2         8.142857
# 1         8.857143

# %% [markdown]
# ## Rushcliffe

# %%
filters = ["areaType=ltla", "areaName=Rushcliffe"]
df, fig = cv.ProcessData(filters)

df.tail(8)
# Out:
#          date    areaName  newCases  newDeaths  newCases_SMA_7  \
# 8  2020-10-28  Rushcliffe        65        0.0       59.571429
# 7  2020-10-29  Rushcliffe        86        1.0       60.714286
# 6  2020-10-30  Rushcliffe        56        1.0       58.428571
# 5  2020-10-31  Rushcliffe        55        0.0       61.285714
# 4  2020-11-01  Rushcliffe        36        1.0       59.714286
# 3  2020-11-02  Rushcliffe        68        2.0       59.714286
# 2  2020-11-03  Rushcliffe        32        0.0       56.857143
# 1  2020-11-04  Rushcliffe         4        1.0       48.142857
#
#    newDeaths_SMA_7
# 8         1.285714
# 7         1.285714
# 6         1.000000
# 5         0.714286
# 4         0.571429
# 3         0.857143
# 2         0.714286
# 1         0.857143

# %% [markdown]
# ## Gedling

# %%
filters = ["areaType=ltla", "areaName=Gedling"]
df, fig = cv.ProcessData(filters)

df.tail(8)
# Out:
#          date areaName  newCases  newDeaths  newCases_SMA_7  newDeaths_SMA_7
# 8  2020-10-28  Gedling        59        1.0       65.285714         1.000000
# 7  2020-10-29  Gedling        54        0.0       62.142857         0.857143
# 6  2020-10-30  Gedling        56        1.0       60.571429         0.857143
# 5  2020-10-31  Gedling        46        2.0       60.714286         1.142857
# 4  2020-11-01  Gedling        37        2.0       58.571429         1.000000
# 3  2020-11-02  Gedling        76        1.0       56.857143         1.142857
# 2  2020-11-03  Gedling        55        1.0       54.714286         1.142857
# 1  2020-11-04  Gedling         6        1.0       47.142857         1.142857

# %% [markdown]
# ## Sheffield

# %%
filters = ["areaType=ltla", "areaName=Sheffield"]
df, fig = cv.ProcessData(filters)

df.tail(8)
# Out:
#          date   areaName  newCases  newDeaths  newCases_SMA_7  newDeaths_SMA_7
# 8  2020-10-28  Sheffield       335        2.0      343.428571         3.714286
# 7  2020-10-29  Sheffield       352        8.0      342.714286         4.714286
# 6  2020-10-30  Sheffield       418        3.0      355.285714         4.285714
# 5  2020-10-31  Sheffield       263        4.0      349.857143         3.857143
# 4  2020-11-01  Sheffield       261       10.0      349.428571         5.142857
# 3  2020-11-02  Sheffield       332        5.0      335.857143         5.142857
# 2  2020-11-03  Sheffield       304        5.0      323.571429         5.285714
# 1  2020-11-04  Sheffield       237        7.0      309.571429         6.000000

# %% [markdown]
# ## Cambridge

# %%
filters = ["areaType=ltla", "areaName=Cambridge"]
df, fig = cv.ProcessData(filters)

df.tail(8)
# Out:
#          date   areaName  newCases  newDeaths  newCases_SMA_7  newDeaths_SMA_7
# 8  2020-10-28  Cambridge        37        0.0       29.428571              0.0
# 7  2020-10-29  Cambridge        21        0.0       26.000000              0.0
# 6  2020-10-30  Cambridge        23        0.0       26.285714              0.0
# 5  2020-10-31  Cambridge        14        0.0       26.857143              0.0
# 4  2020-11-01  Cambridge        19        0.0       26.000000              0.0
# 3  2020-11-02  Cambridge        24        0.0       25.000000              0.0
# 2  2020-11-03  Cambridge        28        0.0       23.714286              0.0
# 1  2020-11-04  Cambridge        13        0.0       20.285714              0.0
